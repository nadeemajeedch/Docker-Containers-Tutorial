# %% [markdown]
# # Check the custom Jupyter stack
#
# This notebook should run inside the image built from `examples/jupyter-project`.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

print("numpy", np.__version__)
print("pandas", pd.__version__)
print("sklearn", sklearn.__version__)

# %%
hours = np.array([1, 2, 3, 4, 5, 6, 7, 8], dtype=float)
scores = np.array([32, 38, 44, 50, 58, 64, 70, 78], dtype=float)
table = pd.DataFrame({"hours": hours, "score": scores})
table

# %%
x = np.linspace(0, 2 * np.pi, 200)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))
ax.set_title("sin(x) from the custom Jupyter image")
ax.set_xlabel("x")
ax.set_ylabel("sin(x)")
plt.show()
